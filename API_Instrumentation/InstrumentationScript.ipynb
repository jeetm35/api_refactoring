# %%
import os

# %%
dst = '/Users/shreya/eclipse/Workspace/InstrumentationHelper/junit'
if not os.path.exists(dst):
    os.mkdir(dst)
API = 'junit4-r4.12' 
API_new = 'junit4-r4.12_All'

# %%
#      myPackage.myXstreamClass.printFile(myPackage.myXstreamClass.getXstream().toXML(condition),"myFilePath.txt");
# iline_1 = 'myPackage.myXstreamClass.printFile(myPackage.myXstreamClass.getXstream().toXML(*),^);'
# print(iline_1.replace('*','word').replace('^','myfilepath'))

iline_1 = "java.lang.reflect.Method m = new Object() {}.getClass().getEnclosingMethod();"
iline_2 =  "String xml=\"<functionCall>\";"
          
iline_3 = "myPackage.myXstreamClass.getXstream().marshal(^,myPackage.myXstreamClass.getStaxWriter()); xml+=myPackage.myXstreamClass.getStrWriter().toString(); "
iline_4 = "xml+=\"</functionCall>\"+\"\\n\";  myPackage.myXstreamClass.printFile(xml,m);"

# %%
cur_src_file_path = None
cur_src_file = None
dst_file_path = None
dst_file = None

with open("parsedJUnit.txt", "r") as changeFile:
    for line in changeFile:
        print(line)
        src_file_path, function, line_no , parameters , returnType = line.split('|')
        
        if ((cur_src_file_path == None) or (src_file_path != cur_src_file_path)):
                
                if(cur_src_file_path != None):
                   
                    dst_file.write(cur_src_file.read())
                    
                    cur_src_file.close()
                    dst_file.close()
                
        
                cur_src_file_path = src_file_path
                
                dst_file_path = cur_src_file_path.replace(API,API_new)
#                 print(dst_src_file_path)
                os.remove(dst_file_path)

                cur_src_file  = open(cur_src_file_path, 'r') 
                dst_file  = open(dst_file_path, 'w')
        
                line_count = 0
                
            
        while(line_count < int(line_no)):
#             print(line_no,line_count)
            src_line = cur_src_file.readline()
#             print(src_line)
            dst_file.write(src_line)
            line_count+=1
        
        print(src_line)
        if(src_line.find('{') != -1):
       

            if(len(parameters)>2):
                dst_file.write('\n')
                dst_file.write('/*-------------------Instrumentation Start-------------------*/ \n')
                dst_file.write('\n')



                dst_file.write(iline_1);
                dst_file.write(iline_2);
                if(parameters[0]!=''):
                    for s in  parameters[1:-1].split(','):
            #                 file_path = function+'_'+s+'_'+returnType
            #                 print(file_path.strip('\n'))  
                        dst_file.write(iline_3.replace('^',s))
                        dst_file.write('\n')
            #                 print(file_path)

                dst_file.write(iline_4);
                dst_file.write('\n')
                dst_file.write('/*-------------------Instrumentation Finish-------------------*/ \n')
                dst_file.write('\n')

        

# Windup              
dst_file.write(cur_src_file.read())                
cur_src_file.close()
dst_file.close()  
changeFile.close()
# Out:
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/extensions/ActiveTestSuite.java|junit.extensions.ActiveTestSuite.run|33|(result)|void
#
#     public void run(TestResult result) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/extensions/ActiveTestSuite.java|junit.extensions.ActiveTestSuite.runTest|40|(test,result)|void
#
#     public void runTest(final Test test, final TestResult result) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/extensions/ActiveTestSuite.java|.run|43|()|void
#
#             public void run() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/extensions/ActiveTestSuite.java|junit.extensions.ActiveTestSuite.runFinished|66|()|void
#
#     synchronized public void runFinished() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/extensions/RepeatedTest.java|junit.extensions.RepeatedTest.countTestCases|21|()|int
#
#     public int countTestCases() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/extensions/RepeatedTest.java|junit.extensions.RepeatedTest.run|26|(result)|void
#
#     public void run(TestResult result) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/extensions/RepeatedTest.java|junit.extensions.RepeatedTest.toString|36|()|String
#
#     public String toString() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/extensions/TestDecorator.java|junit.extensions.TestDecorator.basicRun|22|(result)|void
#
#     public void basicRun(TestResult result) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/extensions/TestDecorator.java|junit.extensions.TestDecorator.countTestCases|26|()|int
#
#     public int countTestCases() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/extensions/TestDecorator.java|junit.extensions.TestDecorator.run|30|(result)|void
#
#     public void run(TestResult result) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/extensions/TestDecorator.java|junit.extensions.TestDecorator.toString|35|()|String
#
#     public String toString() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/extensions/TestDecorator.java|junit.extensions.TestDecorator.getTest|39|()|Test
#
#     public Test getTest() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/extensions/TestSetup.java|junit.extensions.TestSetup.run|19|(result)|void
#
#     public void run(final TestResult result) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/extensions/TestSetup.java|.protect|21|()|void
#
#             public void protect() throws Exception {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertTrue|20|(message,condition)|void
#
#     static public void assertTrue(String message, boolean condition) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertTrue|30|(condition)|void
#
#     static public void assertTrue(boolean condition) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertFalse|38|(message,condition)|void
#
#     static public void assertFalse(String message, boolean condition) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertFalse|46|(condition)|void
#
#     static public void assertFalse(boolean condition) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.fail|53|(message)|void
#
#     static public void fail(String message) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.fail|63|()|void
#
#     static public void fail() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|71|(message,expected,actual)|void
#
#     static public void assertEquals(String message, Object expected, Object actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|85|(expected,actual)|void
#
#     static public void assertEquals(Object expected, Object actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|92|(message,expected,actual)|void
#
#     static public void assertEquals(String message, String expected, String actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|106|(expected,actual)|void
#
#     static public void assertEquals(String expected, String actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|115|(message,expected,actual,delta)|void
#
#     static public void assertEquals(String message, double expected, double actual, double delta) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|128|(expected,actual,delta)|void
#
#     static public void assertEquals(double expected, double actual, double delta) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|137|(message,expected,actual,delta)|void
#
#     static public void assertEquals(String message, float expected, float actual, float delta) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|150|(expected,actual,delta)|void
#
#     static public void assertEquals(float expected, float actual, float delta) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|158|(message,expected,actual)|void
#
#     static public void assertEquals(String message, long expected, long actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|165|(expected,actual)|void
#
#     static public void assertEquals(long expected, long actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|173|(message,expected,actual)|void
#
#     static public void assertEquals(String message, boolean expected, boolean actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|180|(expected,actual)|void
#
#     static public void assertEquals(boolean expected, boolean actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|188|(message,expected,actual)|void
#
#     static public void assertEquals(String message, byte expected, byte actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|195|(expected,actual)|void
#
#     static public void assertEquals(byte expected, byte actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|203|(message,expected,actual)|void
#
#     static public void assertEquals(String message, char expected, char actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|210|(expected,actual)|void
#
#     static public void assertEquals(char expected, char actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|218|(message,expected,actual)|void
#
#     static public void assertEquals(String message, short expected, short actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|225|(expected,actual)|void
#
#     static public void assertEquals(short expected, short actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|233|(message,expected,actual)|void
#
#     static public void assertEquals(String message, int expected, int actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertEquals|240|(expected,actual)|void
#
#     static public void assertEquals(int expected, int actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertNotNull|247|(object)|void
#
#     static public void assertNotNull(Object object) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertNotNull|255|(message,object)|void
#
#     static public void assertNotNull(String message, Object object) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertNull|266|(object)|void
#
#     static public void assertNull(Object object) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertNull|276|(message,object)|void
#
#     static public void assertNull(String message, Object object) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertSame|284|(message,expected,actual)|void
#
#     static public void assertSame(String message, Object expected, Object actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertSame|295|(expected,actual)|void
#
#     static public void assertSame(Object expected, Object actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertNotSame|304|(message,expected,actual)|void
#
#     static public void assertNotSame(String message, Object expected, Object actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.assertNotSame|314|(expected,actual)|void
#
#     static public void assertNotSame(Object expected, Object actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.failSame|318|(message)|void
#
#     static public void failSame(String message) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.failNotSame|323|(message,expected,actual)|void
#
#     static public void failNotSame(String message, Object expected, Object actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.failNotEquals|328|(message,expected,actual)|void
#
#     static public void failNotEquals(String message, Object expected, Object actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/Assert.java|junit.framework.Assert.format|332|(message,expected,actual)|String
#
#     public static String format(String message, Object expected, Object actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/ComparisonCompactor.java|junit.framework.ComparisonCompactor.compact|21|(message)|String
#
#     public String compact(String message) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/ComparisonFailure.java|junit.framework.ComparisonFailure.getMessage|35|()|String
#
#     public String getMessage() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/ComparisonFailure.java|junit.framework.ComparisonFailure.getActual|44|()|String
#
#     public String getActual() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/ComparisonFailure.java|junit.framework.ComparisonFailure.getExpected|53|()|String
#
#     public String getExpected() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/JUnit4TestAdapter.java|junit.framework.JUnit4TestAdapter.countTestCases|33|()|int
#
#     public int countTestCases() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/JUnit4TestAdapter.java|junit.framework.JUnit4TestAdapter.run|37|(result)|void
#
#     public void run(TestResult result) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/JUnit4TestAdapter.java|junit.framework.JUnit4TestAdapter.getTests|42|()|List<Test>
#
#     public List<Test> getTests() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/JUnit4TestAdapter.java|junit.framework.JUnit4TestAdapter.getTestClass|47|()|Class<?>
#
#     public Class<?> getTestClass() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/JUnit4TestAdapter.java|junit.framework.JUnit4TestAdapter.getDescription|51|()|Description
#
#     public Description getDescription() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/JUnit4TestAdapter.java|junit.framework.JUnit4TestAdapter.toString|75|()|String
#
#     public String toString() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/JUnit4TestAdapter.java|junit.framework.JUnit4TestAdapter.filter|79|(filter)|void
#
#     public void filter(Filter filter) throws NoTestsRemainException {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/JUnit4TestAdapter.java|junit.framework.JUnit4TestAdapter.sort|83|(sorter)|void
#
#     public void sort(Sorter sorter) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/JUnit4TestCaseFacade.java|junit.framework.JUnit4TestCaseFacade.toString|14|()|String
#
#     public String toString() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/JUnit4TestCaseFacade.java|junit.framework.JUnit4TestCaseFacade.countTestCases|18|()|int
#
#     public int countTestCases() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/JUnit4TestCaseFacade.java|junit.framework.JUnit4TestCaseFacade.run|22|(result)|void
#
#     public void run(TestResult result) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/JUnit4TestCaseFacade.java|junit.framework.JUnit4TestCaseFacade.getDescription|27|()|Description
#
#     public Description getDescription() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestFailure.java|junit.framework.TestFailure.failedTest|28|()|Test
#
#     public Test failedTest() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestFailure.java|junit.framework.TestFailure.thrownException|35|()|Throwable
#
#     public Throwable thrownException() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestFailure.java|junit.framework.TestFailure.toString|43|()|String
#
#     public String toString() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestFailure.java|junit.framework.TestFailure.trace|51|()|String
#
#     public String trace() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestFailure.java|junit.framework.TestFailure.exceptionMessage|61|()|String
#
#     public String exceptionMessage() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestFailure.java|junit.framework.TestFailure.isFailure|70|()|boolean
#
#     public boolean isFailure() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestListener.java|junit.framework.TestListener.addError|10|(test,e)|void
#
#     public void addError(Test test, Throwable e);
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestListener.java|junit.framework.TestListener.addFailure|15|(test,e)|void
#
#     public void addFailure(Test test, AssertionFailedError e);
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestListener.java|junit.framework.TestListener.endTest|20|(test)|void
#
#     public void endTest(Test test);
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestListener.java|junit.framework.TestListener.startTest|25|(test)|void
#
#     public void startTest(Test test);
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestResult.java|junit.framework.TestResult.addError|36|(test,e)|void
#
#     public synchronized void addError(Test test, Throwable e) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestResult.java|junit.framework.TestResult.addFailure|47|(test,e)|void
#
#     public synchronized void addFailure(Test test, AssertionFailedError e) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestResult.java|junit.framework.TestResult.addListener|57|(listener)|void
#
#     public synchronized void addListener(TestListener listener) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestResult.java|junit.framework.TestResult.removeListener|64|(listener)|void
#
#     public synchronized void removeListener(TestListener listener) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestResult.java|junit.framework.TestResult.endTest|80|(test)|void
#
#     public void endTest(Test test) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestResult.java|junit.framework.TestResult.errorCount|89|()|int
#
#     public synchronized int errorCount() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestResult.java|junit.framework.TestResult.errors|96|()|Enumeration<TestFailure>
#
#     public synchronized Enumeration<TestFailure> errors() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestResult.java|junit.framework.TestResult.failureCount|104|()|int
#
#     public synchronized int failureCount() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestResult.java|junit.framework.TestResult.failures|111|()|Enumeration<TestFailure>
#
#     public synchronized Enumeration<TestFailure> failures() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestResult.java|junit.framework.TestResult.runCount|133|()|int
#
#     public synchronized int runCount() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestResult.java|junit.framework.TestResult.runProtected|140|(test,p)|void
#
#     public void runProtected(final Test test, Protectable p) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestResult.java|junit.framework.TestResult.shouldStop|155|()|boolean
#
#     public synchronized boolean shouldStop() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestResult.java|junit.framework.TestResult.startTest|162|(test)|void
#
#     public void startTest(Test test) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestResult.java|junit.framework.TestResult.stop|175|()|void
#
#     public synchronized void stop() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/framework/TestResult.java|junit.framework.TestResult.wasSuccessful|182|()|boolean
#
#     public synchronized boolean wasSuccessful() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/runner/TestRunListener.java|junit.runner.TestRunListener.testRunStarted|14|(testSuiteName,testCount)|void
#
#     public void testRunStarted(String testSuiteName, int testCount);
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/runner/TestRunListener.java|junit.runner.TestRunListener.testRunEnded|16|(elapsedTime)|void
#
#     public void testRunEnded(long elapsedTime);
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/runner/TestRunListener.java|junit.runner.TestRunListener.testRunStopped|18|(elapsedTime)|void
#
#     public void testRunStopped(long elapsedTime);
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/runner/TestRunListener.java|junit.runner.TestRunListener.testStarted|20|(testName)|void
#
#     public void testStarted(String testName);
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/runner/TestRunListener.java|junit.runner.TestRunListener.testEnded|22|(testName)|void
#
#     public void testEnded(String testName);
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/runner/TestRunListener.java|junit.runner.TestRunListener.testFailed|24|(status,testName,trace)|void
#
#     public void testFailed(int status, String testName, String trace);
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/runner/Version.java|junit.runner.Version.id|11|()|String
#
# 	public static String id() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/runner/Version.java|junit.runner.Version.main|15|(args)|void
#
# 	public static void main(String[] args) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/ResultPrinter.java|junit.textui.ResultPrinter.printDefect|63|(booBoo,count)|void
#
#     public void printDefect(TestFailure booBoo, int count) { // only public for testing purposes
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/ResultPrinter.java|junit.textui.ResultPrinter.getWriter|102|()|PrintStream
#
#     public PrintStream getWriter() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/ResultPrinter.java|junit.textui.ResultPrinter.addError|109|(test,e)|void
#
#     public void addError(Test test, Throwable e) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/ResultPrinter.java|junit.textui.ResultPrinter.addFailure|116|(test,t)|void
#
#     public void addFailure(Test test, AssertionFailedError t) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/ResultPrinter.java|junit.textui.ResultPrinter.endTest|123|(test)|void
#
#     public void endTest(Test test) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/ResultPrinter.java|junit.textui.ResultPrinter.startTest|129|(test)|void
#
#     public void startTest(Test test) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/TestRunner.java|junit.textui.TestRunner.run|61|(testClass)|void
#
#     static public void run(Class<? extends TestCase> testClass) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/TestRunner.java|junit.textui.TestRunner.run|75|(test)|TestResult
#
#     static public TestResult run(Test test) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/TestRunner.java|junit.textui.TestRunner.runAndWait|84|(suite)|void
#
#     static public void runAndWait(Test suite) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/TestRunner.java|junit.textui.TestRunner.testFailed|90|(status,test,e)|void
#
#     public void testFailed(int status, Test test, Throwable e) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/TestRunner.java|junit.textui.TestRunner.testStarted|94|(testName)|void
#
#     public void testStarted(String testName) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/TestRunner.java|junit.textui.TestRunner.testEnded|98|(testName)|void
#
#     public void testEnded(String testName) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/TestRunner.java|junit.textui.TestRunner.doRun|108|(test)|TestResult
#
#     public TestResult doRun(Test test) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/TestRunner.java|junit.textui.TestRunner.doRun|112|(suite,wait)|TestResult
#
#     public TestResult doRun(Test suite, boolean wait) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/TestRunner.java|junit.textui.TestRunner.main|134|(args)|void
#
#     public static void main(String args[]) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/TestRunner.java|junit.textui.TestRunner.start|152|(args)|TestResult
#
#     public TestResult start(String args[]) throws Exception {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/junit/textui/TestRunner.java|junit.textui.TestRunner.setPrinter|201|(printer)|void
#
#     public void setPrinter(ResultPrinter printer) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertTrue|39|(message,condition)|void
#
#     static public void assertTrue(String message, boolean condition) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertTrue|51|(condition)|void
#
#     static public void assertTrue(boolean condition) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertFalse|63|(message,condition)|void
#
#     static public void assertFalse(String message, boolean condition) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertFalse|73|(condition)|void
#
#     static public void assertFalse(boolean condition) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.fail|84|(message)|void
#
#     static public void fail(String message) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.fail|94|()|void
#
#     static public void fail() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertEquals|109|(message,expected,actual)|void
#
#     static public void assertEquals(String message, Object expected,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertEquals|143|(expected,actual)|void
#
#     static public void assertEquals(Object expected, Object actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertNotEquals|158|(message,unexpected,actual)|void
#
#     static public void assertNotEquals(String message, Object unexpected,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertNotEquals|174|(unexpected,actual)|void
#
#     static public void assertNotEquals(Object unexpected, Object actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertNotEquals|197|(message,unexpected,actual)|void
#
#     static public void assertNotEquals(String message, long unexpected, long actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertNotEquals|210|(unexpected,actual)|void
#
#     static public void assertNotEquals(long unexpected, long actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertNotEquals|229|(message,unexpected,actual,delta)|void
#
#     static public void assertNotEquals(String message, double unexpected,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertNotEquals|248|(unexpected,actual,delta)|void
#
#     static public void assertNotEquals(double unexpected, double actual, double delta) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertNotEquals|264|(unexpected,actual,delta)|void
#
#     static public void assertNotEquals(float unexpected, float actual, float delta) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|281|(message,expecteds,actuals)|void
#
#     public static void assertArrayEquals(String message, Object[] expecteds,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|297|(expecteds,actuals)|void
#
#     public static void assertArrayEquals(Object[] expecteds, Object[] actuals) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|312|(message,expecteds,actuals)|void
#
#     public static void assertArrayEquals(String message, boolean[] expecteds,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|326|(expecteds,actuals)|void
#
#     public static void assertArrayEquals(boolean[] expecteds, boolean[] actuals) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|339|(message,expecteds,actuals)|void
#
#     public static void assertArrayEquals(String message, byte[] expecteds,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|351|(expecteds,actuals)|void
#
#     public static void assertArrayEquals(byte[] expecteds, byte[] actuals) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|364|(message,expecteds,actuals)|void
#
#     public static void assertArrayEquals(String message, char[] expecteds,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|376|(expecteds,actuals)|void
#
#     public static void assertArrayEquals(char[] expecteds, char[] actuals) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|389|(message,expecteds,actuals)|void
#
#     public static void assertArrayEquals(String message, short[] expecteds,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|401|(expecteds,actuals)|void
#
#     public static void assertArrayEquals(short[] expecteds, short[] actuals) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|414|(message,expecteds,actuals)|void
#
#     public static void assertArrayEquals(String message, int[] expecteds,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|426|(expecteds,actuals)|void
#
#     public static void assertArrayEquals(int[] expecteds, int[] actuals) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|439|(message,expecteds,actuals)|void
#
#     public static void assertArrayEquals(String message, long[] expecteds,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|451|(expecteds,actuals)|void
#
#     public static void assertArrayEquals(long[] expecteds, long[] actuals) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|467|(message,expecteds,actuals,delta)|void
#
#     public static void assertArrayEquals(String message, double[] expecteds,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|482|(expecteds,actuals,delta)|void
#
#     public static void assertArrayEquals(double[] expecteds, double[] actuals, double delta) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|498|(message,expecteds,actuals,delta)|void
#
#     public static void assertArrayEquals(String message, float[] expecteds,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertArrayEquals|513|(expecteds,actuals,delta)|void
#
#     public static void assertArrayEquals(float[] expecteds, float[] actuals, float delta) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertEquals|550|(message,expected,actual,delta)|void
#
#     static public void assertEquals(String message, double expected,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertEquals|572|(message,expected,actual,delta)|void
#
#     static public void assertEquals(String message, float expected,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertNotEquals|594|(message,unexpected,actual,delta)|void
#
#     static public void assertNotEquals(String message, float unexpected,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertEquals|630|(expected,actual)|void
#
#     static public void assertEquals(long expected, long actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertEquals|643|(message,expected,actual)|void
#
#     static public void assertEquals(String message, long expected, long actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertEquals|655|(expected,actual)|void
#
#     static public void assertEquals(double expected, double actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertEquals|665|(message,expected,actual)|void
#
#     static public void assertEquals(String message, double expected,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertEquals|682|(expected,actual,delta)|void
#
#     static public void assertEquals(double expected, double actual, double delta) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertEquals|699|(expected,actual,delta)|void
#
#     static public void assertEquals(float expected, float actual, float delta) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertNotNull|711|(message,object)|void
#
#     static public void assertNotNull(String message, Object object) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertNotNull|721|(object)|void
#
#     static public void assertNotNull(Object object) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertNull|733|(message,object)|void
#
#     static public void assertNull(String message, Object object) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertNull|746|(object)|void
#
#     static public void assertNull(Object object) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertSame|767|(message,expected,actual)|void
#
#     static public void assertSame(String message, Object expected, Object actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertSame|781|(expected,actual)|void
#
#     static public void assertSame(Object expected, Object actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertNotSame|795|(message,unexpected,actual)|void
#
#     static public void assertNotSame(String message, Object unexpected,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertNotSame|810|(unexpected,actual)|void
#
#     static public void assertNotSame(Object unexpected, Object actual) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertEquals|874|(message,expecteds,actuals)|void
#
#     public static void assertEquals(String message, Object[] expecteds,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertEquals|892|(expecteds,actuals)|void
#
#     public static void assertEquals(Object[] expecteds, Object[] actuals) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertThat|922|(actual,matcher)|void
#
#     public static <T> void assertThat(T actual, Matcher<? super T> matcher) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assert.java|org.junit.Assert.assertThat|954|(reason,actual,matcher)|void
#
#     public static <T> void assertThat(String reason, T actual,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assume.java|org.junit.Assume.assumeTrue|40|(b)|void
#
#     public static void assumeTrue(boolean b) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assume.java|org.junit.Assume.assumeFalse|47|(b)|void
#
#     public static void assumeFalse(boolean b) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assume.java|org.junit.Assume.assumeTrue|58|(message,b)|void
#
#     public static void assumeTrue(String message, boolean b) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assume.java|org.junit.Assume.assumeFalse|65|(message,b)|void
#
#     public static void assumeFalse(String message, boolean b) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assume.java|org.junit.Assume.assumeNotNull|72|(objects)|void
#
#     public static void assumeNotNull(Object... objects) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assume.java|org.junit.Assume.assumeThat|93|(actual,matcher)|void
#
#     public static <T> void assumeThat(T actual, Matcher<T> matcher) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assume.java|org.junit.Assume.assumeThat|116|(message,actual,matcher)|void
#
#     public static <T> void assumeThat(String message, T actual, Matcher<T> matcher) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assume.java|org.junit.Assume.assumeNoException|141|(e)|void
#
#     public static void assumeNoException(Throwable e) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/Assume.java|org.junit.Assume.assumeNoException|155|(message,e)|void
#
#     public static void assumeNoException(String message, Throwable e) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/categories/CategoryFilterFactory.java|org.junit.experimental.categories.CategoryFilterFactory.createFilter|21|(params)|Filter
#
#     public Filter createFilter(FilterFactoryParams params) throws FilterNotCreatedException {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/categories/ExcludeCategories.java|org.junit.experimental.categories.ExcludeCategories.ExcludesAny.describe|48|()|String
#
#         public String describe() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/categories/IncludeCategories.java|org.junit.experimental.categories.IncludeCategories.IncludesAny.describe|48|()|String
#
#         public String describe() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/ParallelComputer.java|org.junit.experimental.ParallelComputer.classes|24|()|Computer
#
#     public static Computer classes() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/ParallelComputer.java|org.junit.experimental.ParallelComputer.methods|28|()|Computer
#
#     public static Computer methods() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/ParallelComputer.java|org.junit.experimental.ParallelComputer.getSuite|55|(builder,classes)|Runner
#
#     public Runner getSuite(RunnerBuilder builder, java.lang.Class<?>[] classes)
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/results/FailureList.java|org.junit.experimental.results.FailureList.result|16|()|Result
#
#     public Result result() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/results/PrintableResult.java|org.junit.experimental.results.PrintableResult.testResult|28|(type)|PrintableResult
#
#     public static PrintableResult testResult(Class<?> type) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/results/PrintableResult.java|org.junit.experimental.results.PrintableResult.testResult|35|(request)|PrintableResult
#
#     public static PrintableResult testResult(Request request) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/results/PrintableResult.java|org.junit.experimental.results.PrintableResult.failureCount|53|()|int
#
#     public int failureCount() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/results/PrintableResult.java|org.junit.experimental.results.PrintableResult.toString|58|()|String
#
#     public String toString() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/theories/internal/AllMembersSupplier.java|org.junit.experimental.theories.internal.AllMembersSupplier.MethodParameterValue.getValue|32|()|Object
#
#         public Object getValue() throws CouldNotGenerateValueException {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/theories/internal/AllMembersSupplier.java|org.junit.experimental.theories.internal.AllMembersSupplier.MethodParameterValue.getDescription|50|()|String
#
#         public String getDescription() throws CouldNotGenerateValueException {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/theories/internal/AllMembersSupplier.java|org.junit.experimental.theories.internal.AllMembersSupplier.getValueSources|65|(sig)|List<PotentialAssignment>
#
#     public List<PotentialAssignment> getValueSources(ParameterSignature sig) throws Throwable {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/theories/internal/Assignments.java|org.junit.experimental.theories.internal.Assignments.allUnassigned|39|(testMethod,testClass)|Assignments
#
#     public static Assignments allUnassigned(Method testMethod,
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/theories/internal/Assignments.java|org.junit.experimental.theories.internal.Assignments.isComplete|49|()|boolean
#
#     public boolean isComplete() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/theories/internal/Assignments.java|org.junit.experimental.theories.internal.Assignments.nextUnassigned|53|()|ParameterSignature
#
#     public ParameterSignature nextUnassigned() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/theories/internal/Assignments.java|org.junit.experimental.theories.internal.Assignments.assignNext|57|(source)|Assignments
#
#     public Assignments assignNext(PotentialAssignment source) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/theories/internal/Assignments.java|org.junit.experimental.theories.internal.Assignments.getActualValues|66|(start,stop)|Object[]
#
#     public Object[] getActualValues(int start, int stop)
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/theories/internal/Assignments.java|org.junit.experimental.theories.internal.Assignments.potentialsForNextUnassigned|75|()|List<PotentialAssignment>
#
#     public List<PotentialAssignment> potentialsForNextUnassigned()
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/theories/internal/Assignments.java|org.junit.experimental.theories.internal.Assignments.getConstructorArguments|126|()|Object[]
#
#     public Object[] getConstructorArguments()
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/main/java/org/junit/experimental/theories/internal/Assignments.java|org.junit.experimental.theories.internal.Assignments.getMethodArguments|131|()|Object[]
#
# ...
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.EverythingWrong.fineAC|68|()|void
#
#         public static void fineAC() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.EverythingWrong.staticA|72|()|void
#
#         public static void staticA() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.EverythingWrong.nonVoidA|80|()|int
#
#         public int nonVoidA() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.EverythingWrong.argumentsA|85|(i)|void
#
#         public void argumentsA(int i) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.EverythingWrong.fineA|89|()|void
#
#         public void fineA() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.EverythingWrong.staticB|93|()|void
#
#         public static void staticB() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.EverythingWrong.nonVoidB|101|()|int
#
#         public int nonVoidB() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.EverythingWrong.argumentsB|106|(i)|void
#
#         public void argumentsB(int i) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.EverythingWrong.fineB|110|()|void
#
#         public void fineB() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.EverythingWrong.staticT|114|()|void
#
#         public static void staticT() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.EverythingWrong.nonVoidT|122|()|int
#
#         public int nonVoidT() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.EverythingWrong.argumentsT|127|(i)|void
#
#         public void argumentsT(int i) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.EverythingWrong.fineT|131|()|void
#
#         public void fineT() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.testFailures|136|()|void
#
#     public void testFailures() throws Exception {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.SubWrong.justFine|150|()|void
#
#         public void justFine() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.validateInheritedMethods|155|()|void
#
#     public void validateInheritedMethods() throws Exception {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.SubShadows.notPublic|163|()|void
#
#         public void notPublic() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.dontValidateShadowedMethods|168|()|void
#
#     public void dontValidateShadowedMethods() throws Exception {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.IgnoredTest.valid|184|()|void
#
#         public void valid() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.IgnoredTest.ignored|189|()|void
#
#         public void ignored() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.IgnoredTest.withReason|194|()|void
#
#         public void withReason() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.ignoreRunner|199|()|void
#
#     public void ignoreRunner() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.compatibility|207|()|void
#
#     public void compatibility() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.Confused.a|215|(b)|void
#
#         public void a(Object b) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.Confused.a|219|()|void
#
#         public void a() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.overloaded|224|()|void
#
#     public void overloaded() throws InitializationError {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.ConstructorParameter.a|233|()|void
#
#         public void a() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.constructorParameter|238|()|void
#
#     public void constructorParameter() throws InitializationError {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.OnlyTestIsIgnored.ignored|245|()|void
#
#         public void ignored() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/running/methods/TestMethodTest.java|org.junit.tests.running.methods.TestMethodTest.onlyIgnoredMethodsIsStillFineTestClass|250|()|void
#
#     public void onlyIgnoredMethodsIsStillFineTestClass() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/TestSystem.java|org.junit.tests.TestSystem.exit|23|(code)|void
#
#     public void exit(int code) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/TestSystem.java|org.junit.tests.TestSystem.out|27|()|PrintStream
#
#     public PrintStream out() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/TestSystem.java|org.junit.tests.TestSystem.outContents|31|()|OutputStream
#
#     public OutputStream outContents() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/validation/anotherpackage/Super.java|org.junit.tests.validation.anotherpackage.Super.a|7|()|void
#
#     public void a() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/validation/BadlyFormedClassesTest.java|org.junit.tests.validation.BadlyFormedClassesTest.FaultyConstructor.someTest|21|()|void
#
#         public void someTest() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/validation/BadlyFormedClassesTest.java|org.junit.tests.validation.BadlyFormedClassesTest.BadBeforeMethodWithLegacyRunner.someTest|39|()|void
#
#         public void someTest() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/validation/BadlyFormedClassesTest.java|org.junit.tests.validation.BadlyFormedClassesTest.constructorException|50|()|void
#
#     public void constructorException() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/validation/BadlyFormedClassesTest.java|org.junit.tests.validation.BadlyFormedClassesTest.noRunnableMethods|56|()|void
#
#     public void noRunnableMethods() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/validation/BadlyFormedClassesTest.java|org.junit.tests.validation.BadlyFormedClassesTest.badBeforeMethodWithLegacyRunner|61|()|void
#
#     public void badBeforeMethodWithLegacyRunner() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/validation/FailedConstructionTest.java|org.junit.tests.validation.FailedConstructionTest.CantConstruct.foo|17|()|void
#
#         public void foo() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/validation/FailedConstructionTest.java|org.junit.tests.validation.FailedConstructionTest.failedConstructionIsTestFailure|22|()|void
#
#     public void failedConstructionIsTestFailure() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/validation/ValidationTest.java|org.junit.tests.validation.ValidationTest.initializationErrorIsOnCorrectClass|20|()|void
#
#     public void initializationErrorIsOnCorrectClass() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/validation/ValidationTest.java|org.junit.tests.validation.ValidationTest.NonStaticBeforeClass.before|27|()|void
#
#         public void before() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/validation/ValidationTest.java|org.junit.tests.validation.ValidationTest.NonStaticBeforeClass.hereBecauseEveryTestClassNeedsATest|31|()|void
#
#         public void hereBecauseEveryTestClassNeedsATest() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/tests/validation/ValidationTest.java|org.junit.tests.validation.ValidationTest.nonStaticBeforeClass|36|()|void
#
#     public void nonStaticBeforeClass() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/validator/AnnotationsValidatorTest.java|org.junit.validator.AnnotationsValidatorTest.ExampleAnnotationValidator.validateAnnotatedClass|27|(testClass)|List<Exception>
#
#         public List<Exception> validateAnnotatedClass(TestClass testClass) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/validator/AnnotationsValidatorTest.java|org.junit.validator.AnnotationsValidatorTest.ExampleAnnotationValidator.validateAnnotatedField|32|(field)|List<Exception>
#
#         public List<Exception> validateAnnotatedField(FrameworkField field) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/validator/AnnotationsValidatorTest.java|org.junit.validator.AnnotationsValidatorTest.ExampleAnnotationValidator.validateAnnotatedMethod|37|(method)|List<Exception>
#
#         public List<Exception> validateAnnotatedMethod(FrameworkMethod method) {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/validator/AnnotationsValidatorTest.java|org.junit.validator.AnnotationsValidatorTest.AnnotationValidatorMethodTest.test|51|()|void
#
#         public void test() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/validator/AnnotationsValidatorTest.java|org.junit.validator.AnnotationsValidatorTest.AnnotationValidatorFieldTest.test|60|()|void
#
#         public void test() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/validator/AnnotationsValidatorTest.java|org.junit.validator.AnnotationsValidatorTest.AnnotationValidatorClassTest.test|67|()|void
#
#         public void test() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/validator/AnnotationsValidatorTest.java|org.junit.validator.AnnotationsValidatorTest.validatorIsCalledForAClass|72|()|void
#
#     public void validatorIsCalledForAClass() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/validator/AnnotationsValidatorTest.java|org.junit.validator.AnnotationsValidatorTest.validatorIsCalledForAMethod|78|()|void
#
#     public void validatorIsCalledForAMethod() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/validator/AnnotationsValidatorTest.java|org.junit.validator.AnnotationsValidatorTest.validatorIsCalledForAField|84|()|void
#
#     public void validatorIsCalledForAField() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/validator/AnnotationValidatorFactoryTest.java|org.junit.validator.AnnotationValidatorFactoryTest.createAnnotationValidator|19|()|void
#
#     public void createAnnotationValidator() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/validator/AnnotationValidatorFactoryTest.java|org.junit.validator.AnnotationValidatorFactoryTest.exceptionWhenAnnotationWithNullClassIsPassedIn|26|()|void
#
#     public void exceptionWhenAnnotationWithNullClassIsPassedIn() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/validator/AnnotationValidatorFactoryTest.java|org.junit.validator.AnnotationValidatorFactoryTest.ValidatorWithNullValue.value|36|()|Class<? extends AnnotationValidator>
#
#         public Class<? extends AnnotationValidator> value() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/validator/AnnotationValidatorFactoryTest.java|org.junit.validator.AnnotationValidatorFactoryTest.ValidatorWithNullValue.annotationType|40|()|Class<? extends Annotation>
#
#         public Class<? extends Annotation> annotationType() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/validator/AnnotationValidatorFactoryTest.java|org.junit.validator.AnnotationValidatorFactoryTest.exceptionWhenAnnotationValidatorCantBeCreated|53|()|void
#
#     public void exceptionWhenAnnotationValidatorCantBeCreated() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/validator/PublicClassValidatorTest.java|org.junit.validator.PublicClassValidatorTest.acceptsPublicClass|21|()|void
#
#     public void acceptsPublicClass() {
#
# /Users/shreya/eclipse/Workspace/InstrumentationHelper/junit4-r4.12/src/test/java/org/junit/validator/PublicClassValidatorTest.java|org.junit.validator.PublicClassValidatorTest.rejectsNonPublicClass|34|()|void
#
#     public void rejectsNonPublicClass() {

# %%
parameters = '(ab,b)'
'_'.join(parameters[1:-1].split(','))
# Out:
# 'ab_b'

# %%
print('|'.join('a'+'b'))
# Out:
# a|b

# %%
function
# Out:
# 'junit.extensions.TestSetup.run'

# %%
file_path
# Out:
# '"junit.extensions.RepeatedTest.run_result_void\n"'

# %%
returnType
# Out:
# 'String'

# %%
s="public List<Exception> validateTestClass(TestClass testClass)";
s.find('{')
# Out:
# -1
