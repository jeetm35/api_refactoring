# %%
import os

# %%
xml_src_dir = '/Users/shreya/eclipse/Workspace/InstrumentationHelper/XmlDump/'
xml_dst_dir = '/Users/shreya/eclipse/Workspace/InstrumentationHelper/XmlDump_start/'

# %%
for file in os.listdir(xml_src_dir):
    print(file)
    
    f_s = open(xml_src_dir+'/'+file,"r")
    
    f_d = open(xml_dst_dir+'/'+file,"w")
    f_d.write("<start>\n") 

    if(file[0]=='.'):
        continue
    with open(xml_src_dir+'/'+file, "rt", encoding="utf-8") as f:  
        line = f_s.read()
        
        f_d.write(line)
    
    f_d.write("</start>\n")
    
    
    f_s.close()
    f_d.close()

# with open(xml_file_src_path, "r") as changeFile:
    
#     for line in changeFile:
#         print(line)
# Out:
# junit.framework.Assert.assertEquals_int.arg0_int.arg1_void
# junit.framework.Assert.assertEquals_java.lang.Object.arg0_java.lang.Object.arg1_void
# junit.framework.Assert.assertEquals_java.lang.String.arg0_int.arg1_int.arg2_void
# junit.framework.Assert.assertEquals_java.lang.String.arg0_java.lang.Object.arg1_java.lang.Object.arg2_void
# junit.framework.Assert.assertEquals_java.lang.String.arg0_java.lang.String.arg1_java.lang.String.arg2_void
# junit.framework.Assert.assertEquals_java.lang.String.arg0_java.lang.String.arg1_void
# junit.framework.Assert.assertEquals_java.lang.String.arg0_long.arg1_long.arg2_void
# junit.framework.Assert.assertEquals_long.arg0_long.arg1_void
# junit.framework.Assert.assertFalse_boolean.arg0_void
# junit.framework.Assert.assertFalse_java.lang.String.arg0_boolean.arg1_void
# junit.framework.Assert.assertNotNull_java.lang.Object.arg0_void
# junit.framework.Assert.assertNotNull_java.lang.String.arg0_java.lang.Object.arg1_void
# ...
